# %%
# %matplotlib notebook
import pandas as pd

# %%
df = pd.read_csv("data/tcr-0522-140735.csv")

# range = (df['timestamp']>2075) & (df['timestamp']<2200)
range = (df['timestamp']>0) & (df['timestamp']<5000)

ax = df[range].plot(x="timestamp", y="talonfx_10__selected_sensor_velocity", style='r.-', label="10")
df[range].plot(x="timestamp", y="talonfx_12__selected_sensor_velocity", style='b.-', ax=ax, label="12")
df[range].plot(x="timestamp", y="talonfx_13__selected_sensor_velocity", style='g.-', ax=ax, label="13")
ax.set_title("Velocity")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Velocity')
