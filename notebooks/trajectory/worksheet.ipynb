# %%
from trajectory import *

# %%
t = TrajectoryTelemetry("data/tcr-0525-175221.csv") #, wheel_diameter_in=3.3)
t.end_pose()
# Out:
#      traj_x  traj_y    odom_x    odom_y  odom_deg
# 697     3.0     0.0  3.046247  0.019446      1.32

# %%
interval = t.make_interval() #start=6200)
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(16,16), sharex=False)
t.plot_trajectory(ax=ax1, interval=interval)
t.plot_velocity(ax=ax2, controller=True, interval=interval)

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(16,9))
t.plot_yaw(ax=ax1, gyro=True)

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, sharex=True)
interval = t.make_interval(end=1600)
t.df[interval].plot(x='timestamp', y='traj_vel', ax=ax1)
t.df[interval].plot(x='timestamp', y='traj_accel', ax=ax2)
t.df[interval].plot(x='timestamp', y='traj_time', ax=ax3)
ax1.grid()
ax2.grid()
ax3.grid()

# %%
print(t.df[t.interval]['timestamp'].diff().describe())
t.df[t.interval]['timestamp'].diff().plot.hist(bins=20)
# Out:
# count    464.00000
# mean       5.00000
# std        1.35971
# min        1.00000
# 25%        5.00000
# 50%        5.00000
# 75%        5.00000
# max       14.00000
# Name: timestamp, dtype: float64
# <AxesSubplot:ylabel='Frequency'>

# %%
t.df.columns
# Out:
# Index(['timestamp', 'traj_x', 'traj_y', 'traj_vel', 'traj_accel', 'traj_deg',
#        'traj_time', 'hc_vy', 'hc_vx', 'hc_omega', 'odom_x', 'odom_y',
#        'gyro_deg', 'odom_deg', 't10_setpoint', 't11_setpoint', 't12_setpoint',
#        't13_setpoint', 't10_velocity', 't11_velocity', 't12_velocity',
#        't13_velocity', 'talon_setpoint_avg', 'talon_velocity_avg'],
#       dtype='object')
