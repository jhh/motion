# %%
# %matplotlib notebook
import pandas as pd

# %%
df = pd.read_csv("data/tcr-0522-140735.csv")

df.plot.scatter(x="timestamp", y="talonfx_10__selected_sensor_velocity", marker='.')

df.describe()
# Out:
# <img src="data:image/png;base64,..." width="640">
#          timestamp  talonfx_10__closed_loop_setpoint__pid_0_  \
# count  1231.000000                               1231.000000
# mean   3220.383428                               3726.489846
# std    1772.653694                               4347.071776
# min     240.000000                               -980.000000
# 25%    1679.500000                                  0.000000
# 50%    3217.000000                                  0.000000
# 75%    4754.500000                               9021.000000
# max    6292.000000                              10436.000000
#
#        talonfx_10__output_voltage  talonfx_10__selected_sensor_velocity  \
# count                 1231.000000                           1231.000000
# mean                     2.099501                           3683.502843
# std                      2.482906                           4313.588222
# min                     -0.948387                           -404.000000
# ...

# %%
df.columns
# Out:
# Index(['timestamp', 'talonfx_10__closed_loop_setpoint__pid_0_',
#        'talonfx_10__output_voltage', 'talonfx_10__selected_sensor_velocity',
#        'talonfx_11__closed_loop_setpoint__pid_0_',
#        'talonfx_11__output_voltage', 'talonfx_11__selected_sensor_velocity',
#        'talonfx_12__closed_loop_setpoint__pid_0_',
#        'talonfx_12__output_voltage', 'talonfx_12__selected_sensor_velocity',
#        'talonfx_13__closed_loop_setpoint__pid_0_',
#        'talonfx_13__output_voltage', 'talonfx_13__selected_sensor_velocity'],
#       dtype='object')

# %%
df[(df['timestamp'] > -1000) & (df['timestamp'] < 3000)].plot.scatter(x="timestamp", y="talonfx_11__selected_sensor_velocity", marker='.')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='timestamp', ylabel='talonfx_11__selected_sensor_velocity'>

# %%
df[(df['timestamp'] > 0) & (df['timestamp'] < 3000)].plot.scatter(x="timestamp", y="talonfx_12__selected_sensor_velocity", marker='.')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='timestamp', ylabel='talonfx_12__selected_sensor_velocity'>

# %%
df[(df['timestamp'] > 0) & (df['timestamp'] < 3000)].plot.scatter(x="timestamp", y="talonfx_13__selected_sensor_velocity", marker='.')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='timestamp', ylabel='talonfx_13__selected_sensor_velocity'>

# %%
df[(df['timestamp'] > 0) & (df['timestamp'] < 6000)].plot.scatter(x="timestamp", y="talonfx_10__output_voltage", marker='.')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='timestamp', ylabel='talonfx_10__output_voltage'>

# %%
df[(df['timestamp'] > 0) & (df['timestamp'] < 6000)].plot.scatter(x="timestamp", y="talonfx_11__output_voltage", marker='.')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='timestamp', ylabel='talonfx_11__output_voltage'>

# %%
df[(df['timestamp'] > 0) & (df['timestamp'] < 3000)].plot.scatter(x="timestamp", y="talonfx_12__output_voltage", marker='.')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='timestamp', ylabel='talonfx_12__output_voltage'>

# %%
df[(df['timestamp'] > 0) & (df['timestamp'] < 3000)].plot.scatter(x="timestamp", y="talonfx_13__output_voltage", marker='.')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='timestamp', ylabel='talonfx_13__output_voltage'>

# %%
df[(df['timestamp'] > 0) & (df['timestamp'] < 3000)].plot.scatter(x="timestamp", y="talonfx_10__closed_loop_setpoint__pid_0_", marker='.')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='timestamp', ylabel='talonfx_10__closed_loop_setpoint__pid_0_'>

# %%
df[(df['timestamp'] > 0) & (df['timestamp'] < 3000)].plot.scatter(x="timestamp", y="talonfx_11__closed_loop_setpoint__pid_0_", marker='.')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='timestamp', ylabel='talonfx_11__closed_loop_setpoint__pid_0_'>

# %%
df[(df['timestamp'] > 0) & (df['timestamp'] < 3000)].plot.scatter(x="timestamp", y="talonfx_12__closed_loop_setpoint__pid_0_", marker='.')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='timestamp', ylabel='talonfx_12__closed_loop_setpoint__pid_0_'>

# %%
df[(df['timestamp'] > 0) & (df['timestamp'] < 3000)].plot.scatter(x="timestamp", y="talonfx_13__closed_loop_setpoint__pid_0_", marker='.')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='timestamp', ylabel='talonfx_13__closed_loop_setpoint__pid_0_'>
