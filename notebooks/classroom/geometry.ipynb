# %%
# %matplotlib notebook
from matplotlib import pyplot as plt
from wpimath.geometry import Translation2d

# %%
a = Translation2d(1, 1)
b = Translation2d(1, 3)

print("plus", a+b)
print("distance", b.distance(a))
# Out:
# plus Translation2d(x=2.000000, y=4.000000)
# distance 2.0

# %%
x = [1, 1]
y = [1, 3]
a = ["A", "B"]
fig, ax = plt.subplots()
ax.set_xlim(0, 2)
ax.set_ylim(0, 4)
ax.scatter(x, y)
for i, txt in enumerate(a):
    ax.text(x[i]+0.1, y[i], txt)
# Out:
# <img src="data:image/png;base64,..." width="640">
