# %%
# %matplotlib inline
import pandas as pd
from keeper import Action

# %%
url = "http://localhost.proxyman.io:8000/last_action/"
action = Action(url=url)
print(f"Activity:    {action.name}")
print(f"Description: {action.description}")
print(f"Created At:  {action.created_at}")
# Out:
# Activity:    Trajectory Testing
# Description: 3.0m double curve trajectory
# Created At:  2021-05-02 09:51

# %%
action.dataframe.plot.scatter(x='poseX', y='poseY')
# Out:
# <AxesSubplot:xlabel='poseX', ylabel='poseY'>
